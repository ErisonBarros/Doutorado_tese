# %% [markdown]
# <a href="https://colab.research.google.com/github/ErisonBarros/Doutorado_tese/blob/master/Analise_Exploarat%C3%B3ria_dos_Dados_BR_408.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='Green'>Analise Exploratória dos Dados </font>
#
# # <font color='Grey'> Gráficos Interativos </font>

# %% [markdown]
# **Carregamento de bibliotecas:**

# %%
# Display all results in a single notebook input:
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# !pip install osmnx

# %%
# !pip install pandas
# !pip instal numpy
# !pip install geopandas
# !pipi install os
# !pip install pysal
# !pipi install pickle

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import os
import pysal
from pyproj import CRS
from shapely.geometry import Point, MultiPoint, Polygon, mapping
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import networkx as nx
from fiona.crs import from_epsg
import pickle

# %% [markdown]
# ## Código do R dentro do Python

# %%
# !pip install rpy2

# %%
import rpy2.robjects as ro

# %% [markdown]
# **Exemplo**

# %%
ro.r('x=c(1,2,3)')
# Out:
# R object with classes: ('numeric',) mapped to:
# [1.000000, 2.000000, 3.000000]

# %% [markdown]
# # Instalação e Importação das Biblioteca

# %% [markdown]
# Bibliotecas de Analise Utilizadas
#
# 1.   Ler dados CSV
# 2.   Ler Shape Files

# %% [markdown]
# # Ler dados CSV
#
# **Links**

# %% [markdown]
# https://pypi.org/project/pywedge/

# %% [markdown]
# https://pywedge-make-charts.herokuapp.com/

# %% [markdown]
# ## Ler ShapeFile

# %% [markdown]
# **Importar as Bibliotecas**

# %%
# !pip install geopandas
# !pip install descartes 
# !pip install pyshp
# !pip install pandas

# %%
# Import necessary modules
import geopandas as gpd

# %%
print("Loading Shapefile...")
# Out:
# Loading Shapefile...

# %%
# Set filepath
shp = "/content/BR408_REGIAO_FAIXA.shp"

# %%
# Read file using gpd.read_file()
shapefile = gpd.read_file(shp)

# %% [markdown]
# **Definir o Sistema de Refrencia **

# %%
shapefile = shapefile.to_crs(CRS("WGS84"));

# %% [markdown]
# **Tipo de Dado**

# %%
# Tipo de Dado
type(shapefile)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# Cabercalho do Dado
shapefile.head()
# Out:
#             ID_UNICO  ...                                           geometry
# 0  200ME70374N104342  ...  POLYGON ((-35.30186 -7.52222, -35.30186 -7.522...
# 1  200ME70376N104342  ...  POLYGON ((-35.29999 -7.52267, -35.29999 -7.522...
# 2  200ME70374N104344  ...  POLYGON ((-35.30251 -7.52206, -35.30251 -7.522...
# 3  200ME70378N104342  ...  POLYGON ((-35.29814 -7.52283, -35.29823 -7.522...
# 4  200ME70376N104344  ...  POLYGON ((-35.30189 -7.52175, -35.30159 -7.521...
#
# [5 rows x 29 columns]

# %%
shap_dados=shapefile

# %%
type(shap_dados)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# # Plotar Mapa

# %%
# Plotar
shapefile.plot()
plt.show()

# %% [markdown]
# #Iniciando a **Analise Exploratória de Dados**

# %% [markdown]
# Criar diferentes tipos de gráficos de visualização de Dados de forma interativa, ou seja, sem a necessidade de configurações adicionais para facilitar a analise exploratória dos dados
#
# * Gráfico de dispersão
# * Gráfico de pizza
# * Bar Plot
# * Violino
# * Box Plot
# * Gráfico de Distribuição
# * Histograma
# * Gráfico de Correlação

# %% [markdown]
# [texto do link](https://)
#
# ## O Para usarmos a Biblioteca "Pywedge_Charts" precisamos dos seguintes parâmetros:
#
#
# **1° Dataframe**
#
# **2° c** = Eliminar colunas redundantes (Id por exemplo)
#
# **3° y** = A variável Target (classe, etc)

# %% [markdown]
# ### ler dados CSV

# %%
#Comando de Instalação
# !pip install pywedge

# %%
#Importação de Bibliotecas
import pywedge as pw

# %%
#importação da fonte de dados
import pandas as pd
train = pd.read_csv('/content/ANALISE_GEODA_REGIÃO FAIXA.csv')

# %%
train.head()
# Out:
#             ID_UNICO  MASC  FEM  POP  ...  CATEGORIES  UN_TIPO_GR  UN_ZONA  UN_COD_ZON
# 0  200ME70374N104342     2    2    4  ...           6         200   URBANO         1.0
# 1  200ME70376N104342     8    7   15  ...           7         200   URBANO         1.0
# 2  200ME70374N104344    14   12   26  ...           7         200   URBANO         1.0
# 3  200ME70378N104342     0    0    0  ...           6         200   URBANO         1.0
# 4  200ME70376N104344     2    1    3  ...           7         200   URBANO         1.0
#
# [5 rows x 31 columns]

# %% [markdown]
# # **Resumo Estátistico**

# %% [markdown]
# **Dado CSV**

# %%
train.describe()
# Out:
#               MASC          FEM  ...  CATEGORIES  UN_COD_ZON
# count   453.000000   453.000000  ...  453.000000  453.000000
# mean     21.726269    23.046358  ...    6.412804    0.885210
# std      81.918155    87.729245  ...    0.497351    0.319121
# min       0.000000     0.000000  ...    6.000000    0.000000
# 25%       0.000000     0.000000  ...    6.000000    1.000000
# 50%       1.000000     1.000000  ...    6.000000    1.000000
# 75%       9.000000     8.000000  ...    7.000000    1.000000
# max    1411.000000  1491.000000  ...    8.000000    1.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# **Dado Shapefile**

# %%
shapefil.describre()

# %% [markdown]
# # Histograma

# %%
train.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcac3334c18>,
# ...
#       dtype=object)

# %% [markdown]
# # Analisando os  dados  **Regiões Contidas sobre a Faixa de Domínio da BR-408**

# %%
#Input de Parâmetros
mc = pw.Pywedge_Charts(train, c='CATEGORIES', y = 'ocorr_2010')

# %%
#Run
charts = mc.make_charts()
# Out:
# HTML(value='<h2>Pywedge Make_Charts </h2>')
# ...

# %% [markdown]
# #Fim

# %% [markdown]
# ## Valeu!

# %% [markdown]
# ### #Links - Laboaratório de Automação Topográfica - Labat s <a href="https://linktr.ee/cienciadosdados">https://sites.google.com/view/labat/01</a>

# %% [markdown]
# ### #YouTube - Mais Aulas como essa no YouTube <a href="https://erisonbarros.page.link/labat">https://www.youtube.com/channel/UCf-oBG1kqnpAFrzaiW93kmg</a>
